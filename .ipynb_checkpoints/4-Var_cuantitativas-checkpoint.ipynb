# %% [markdown]
# ### Instituto Superior Tecnologico Quito

# %% [markdown]
# ![jupyter](img/itq.png)

# %% [markdown]
# **Nombre:** Alan Velasco, Maiccol Zurita
#
# **Fecha:** 30/03/2026

# %%
# Creación aleatoria de datos
import numpy as np
X = np.array([0.5, 23, 0.3, 4.5, 0.3, 0.5,
              -28, -50, 60, -100, -10, -11, 13, 19, 1, 9])

# %%
# Medidas de tendencia central
from scipy import stats
media = np.mean(X)
mediana = np.median(X)
moda, _ = stats.mode(X)
print('media: ', media)
print('mediana: ', mediana)
print('moda :', moda)
# Out:
# media:  -4.24375
# mediana:  0.5
# moda : 0.3

# %%
# Medidas de posición
import numpy as np
import matplotlib.pyplot as plt

Q1 = np.percentile(X, 25)
Q3 = np.percentile(X, 75)
RIC = Q3 - Q1
lim_inf = Q1 - 1.5*RIC
lim_sup = Q3 + 1.5*RIC

print('RIC :', RIC)
print('limite inferior :', lim_inf)
print('limite superior :', lim_sup)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Medidas de posición
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#       5 Q1 = np.percentile(X, 25)
#       6 Q3 = np.percentile(X, 75)
#
# File ~\anaconda3\envs\machine2\Lib\site-packages\matplotlib\__init__.py:264
#     259         if parse_version(module.__version__) < parse_version(minver):
#     260             raise ImportError(f"Matplotlib requires {modname}>={minver}; "
#     261                               f"you have {module.__version__}")
# --> 264 _check_versions()
#     267 # The decorator ensures this always returns the same handler (and it is only
#     268 # attached once).
#     269 @functools.cache
#     270 def _ensure_handler():
#
# File ~\anaconda3\envs\machine2\Lib\site-packages\matplotlib\__init__.py:249, in _check_versions()
#     245 def _check_versions():
#     246
#     247     # Quickfix to ensure Microsoft Visual C++ redistributable
#     248     # DLLs are loaded before importing kiwisolver
# --> 249     from . import ft2font  # noqa: F401
#     251     for modname, minver in [
#     252             ("cycler", "0.10"),
#     253             ("dateutil", "2.7"),
#    (...)    256             ("pyparsing", "2.3.1"),
#     257     ]:
#     258         module = importlib.import_module(modname)
#
# ImportError: cannot import name 'ft2font' from partially initialized module 'matplotlib' (most likely due to a circular import) (C:\Users\Usuario\anaconda3\envs\machine2\Lib\site-packages\matplotlib\__init__.py)

# %%
# Dibuja el diagrama de box and whiskers y determina visualmente el número de outliers
plt.boxplot(X)
plt.grid()
plt.title("Diagrama de caja y bigotes")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Dibuja el diagrama de box and whiskers y determina visualmente el número de outliers
# ----> 2 plt.boxplot(X)
#       3 plt.grid()
#       4 plt.title("Diagrama de caja y bigotes")
#
# NameError: name 'plt' is not defined

# %%
# Medidas de dispersión
desvest = np.std(X)
print('Desviación típica: ', desvest)
print('Varianza: ', desvest**2)
# Out:
# Desviación típica:  33.521242681880096
# Varianza:  1123.6737109375

# %%
# Medidas de distribución
asimetria = stats.skew(X)
curtosis = stats.kurtosis(X, fisher=True) # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.kurtosis.html
print('Asimetría ', np.round(asimetria, 4))
print('Curtosis ', np.round(curtosis, 4))

if curtosis>0:
    print('Distribución Leptocúrtica')
elif curtosis<0:
    print('Distribución Platicúrtica')
else:
    print('Distribución Mesocúrtica')
# Out:
# Asimetría  -1.1302
# Curtosis  2.2858
# Distribución Leptocúrtica

# %%
# Cargar el set de datos de Iris
from sklearn import datasets
from pprint import pprint
iris = datasets.load_iris()
#pprint(iris)
X = iris.data
y = iris.target

# ¿Qué tipo de asimetría se observa en la variable "longitud del pétalo"?
#???

# ¿A qué tipo de distribución se ajusta la variable "ancho del sépalo", según su curtosis?
#???

# %%
# EJERCICIO EXTRA SOBRE EL DATASET DE IRIS
# Extraer la media y la desviación típica de cada variable en función de la clase y representarlo en un gráfico (plt.errorbar)
???
# Out:
# Object `?` not found.

# %% [markdown]
# El resultado debería ser algo como esto:
# <img src="images/errorbar.png">
