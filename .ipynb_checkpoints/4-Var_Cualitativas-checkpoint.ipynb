# %% [markdown]
# ### Instituto Superior Tecnologico Quito

# %% [markdown]
# ![jupyter](img/itq.png)

# %% [markdown]
# **Nombre:** Alan Velasco, Maiccol Zurita
#
# **Fecha:** 30/03/2026

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Master' 'Secundaria' 'Grado'
#  'Grado' 'Master' 'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Master' 'Grado' 'Grado' 'Secundaria' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Doctorado' 'Master'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Master'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Grado' 'Master' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Master' 'Grado' 'Grado'
#  'Master' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Master' 'Master'
#  'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Grado' 'Grado' 'Master' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Doctorado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Doctorado' 'Grado'
#  'Bachillerato' 'Master' 'Grado' 'Doctorado' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Doctorado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Master'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Master' 'Secundaria' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Master' 'Secundaria' 'Secundaria' 'Doctorado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Master' 'Master' 'Master' 'Secundaria' 'Grado' 'Grado'
#  'Doctorado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Master' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Doctorado' 'Master' 'Doctorado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Master'
#  'Doctorado' 'Grado' 'Secundaria' 'Secundaria' 'Master' 'Doctorado'
#  'Master' 'Grado' 'Grado' 'Master' 'Master' 'Secundaria' 'Master' 'Grado'
#  'Bachillerato' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creamos un data frame con el nivel de estudio ya con los datos de antes 
df = pd.DataFrame({'Nivel de estudios': nivel_estudios})

# Calcullamos la frecuencia 
frecuencia = df['Nivel de estudios'].value_counts()
#imprimimos el resultado 
print(frecuencia)
# Out:
# Nivel de estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
#Creamos el diagrama de barras 
frecuencia.plot(kind='bar')

plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras con Pandas')
plt.show()

# %%
#Creamos el diagrama pastel 
frecuencia.plot(
    kind='pie',
    autopct='%1.2f%%',
    ylabel='',
    title='Diagrama de sectores con Pandas'
)

plt.show()
