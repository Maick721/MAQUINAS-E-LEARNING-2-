# %% [markdown]
# ### Instituto Superior Tecnologico Quito

# %% [markdown]
# ![jupyter](img/itq.png)

# %% [markdown]
# **Nombre:** Maiccol Zurita
#
# **Fecha:** 30/03/2026

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Master' 'Doctorado' 'Secundaria' 'Grado' 'Doctorado'
#  'Master' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Master' 'Master' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Doctorado' 'Grado' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Secundaria'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Master' 'Master' 'Bachillerato' 'Master' 'Secundaria'
#  'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Master' 'Doctorado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria'
#  'Master' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Master' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Grado' 'Doctorado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Master' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Master' 'Master' 'Master' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Master' 'Grado' 'Grado' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Master'
#  'Secundaria' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Doctorado' 'Master' 'Grado' 'Secundaria' 'Grado' 'Master' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Master' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Doctorado' 'Grado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Master' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Grado' 'Master' 'Grado' 'Grado' 'Doctorado' 'Secundaria'
#  'Grado' 'Secundaria' 'Master' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Secundaria' 'Doctorado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Secundaria' 'Master' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Master' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Doctorado' 'Master' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Doctorado' 'Doctorado' 'Secundaria' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Secundaria' 'Grado' 'Bachillerato'
#  'Bachillerato' 'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Doctorado' 'Bachillerato' 'Master' 'Grado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Grado' 'Master' 'Grado' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Grado' 'Grado' 'Bachillerato'
#  'Doctorado' 'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Secundaria' 'Bachillerato' 'Secundaria' 'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creamos un data frame con el nivel de estudio ya con los datos de antes 
df = pd.DataFrame({'Nivel de estudios': nivel_estudios})

# Calcullamos la frecuencia 
frecuencia = df['Nivel de estudios'].value_counts()
#imprimimos el resultado 
print(frecuencia)
# Out:
# Nivel de estudios
# Bachillerato    172
# Grado           145
# Secundaria      110
# Master           52
# Doctorado        21
# Name: count, dtype: int64

# %%
#Creamos el diagrama de barras 
frecuencia.plot(kind='bar')

plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras con Pandas')
plt.show()

# %%
#Creamos el diagrama pastel 
frecuencia.plot(
    kind='pie',
    autopct='%1.2f%%',
    ylabel='',
    title='Diagrama de sectores con Pandas'
)

plt.show()

# %% [markdown]
# **Github:** https://github.com/Maick721/MAQUINAS-E-LEARNING-2-.git
